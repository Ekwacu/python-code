# %%
### Important libries to import
import xarray as xr
import numpy as np
import cmocean # for perceptually uniform colormaps
import cartopy as cr # for geographic mapping
import cartopy.crs as ccrs # for map projections
import matplotlib.pyplot as plt # plotting tool

from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from descartes import PolygonPatch
import matplotlib.path as mplPath
from shapely.geometry.polygon import Polygon
import geopandas as gpd
import shapefile as shp
import regionmask

# %%
rh = xr.open_dataset('D:/Folder_2023/Research/Joan/rh_obs_days.nc')
#rh
rh.data_vars
# Out:
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     r          (time, latitude, longitude) float32 ...

# %%
#wspd.lev  # print presure level
#ds = rh.sel(bnds=1) #selecting to the pressure level
#ds

# %%
ds1 = rh.sel(time='2022-04-22 11:00:00')
#ds1

# %%
ds1.r.plot()
