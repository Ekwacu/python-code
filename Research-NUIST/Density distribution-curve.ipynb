# %% [markdown]
# ### Density Distribution plot for Rainfall-created by Samuel Ekwacu

# %%
import pandas as pd
# Read in data and examine first 10 rows
home_dir = 'D:/Folder_2023/SATELITE_DATA/'
rfe = pd.read_csv(home_dir + 'Climatology_RFE.csv')
rfe.head(10)
# Out:
#     station  Annual_clim  JJAS_clim
# 0     Hamad         4.94       4.80
# 1     Naama       573.05     500.14
# 2     Aroma       169.17     157.28
# 3    Atbara        59.38      56.37
# 4  Damazine       685.93     593.74
# 5   Dongola        10.39      10.34
# 6     Duiem       246.69     238.09
# 7   Elobeid       341.74     316.88
# 8     Nahud       337.35     306.49
# 9    Fasher       193.25     183.81

# %%
#Density Plot and Histogram of all arrival delays
sns.distplot(rfe['JJAS_clim'], hist=True, kde=True, 
             bins=int(50/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 2})
#plt.xlim([-10, 10])
plt.title('Density plot and Histogram of JJAS climatology',fontsize=11, fontweight='bold')
plt.xlabel('Annual Rainfall (mm)',fontsize=10, fontweight='bold')
plt.ylabel('Density',fontsize=10, fontweight='bold')
plt.savefig(home_dir + 'JJAS_clim-Density curve.png')
plt.show()
# Out:
# C:\Users\Samuel-NUIST\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns

# matplotlib histogram
plt.hist(flights['Annual_clim'], color = 'blue', edgecolor = 'black',
         bins = int(70/5))

# seaborn histogram
sns.distplot(flights['1981'], hist=True, kde=False, 
             bins=int(70/5), color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
plt.title('Histogram of Daily Rainfall density distribution')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Days')
# Out:
# C:\Users\Samuel-NUIST\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Days')

# %% [markdown]
# ### God Provides
