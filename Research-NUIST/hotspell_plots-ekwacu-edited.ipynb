# %% [markdown]
# ### Python script for ploting line Graphs

# %% [markdown]
# ### Written by Samuel Ekwacu-Research Work NUIST 2022

# %%
## Import the necessary libraries to enable us perform our analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Define the data path

home_dir = 'F:/Folder_2022/Research/'

# %%
## Read in the data using the appropriate Library and by defining the correct path

hotspell = pd.read_csv(home_dir +'Hotspell_Tmin_JK.csv')
#hotspell             ## Prints out a sample of the data
#hotspell.info()      ## describe your data
hotspell.columns     ## Check the column headers
#hotspell.shape       ## Check the number of rows and columns
#hotspell.describe()  ## Get summary statistics about your data
#hotspell[["Hotspells12_BR"]].describe()  ## Summary statistics on particular columns as a dataframe
#hotspell["Hotspells12_BR"].describe()  ## Summary statistics on particular columns as a series
#hotspell.sort_values(by="Hotspells12_BR", ascending = False) ## Sort the data in descending order
# Out:
# Index(['Years', 'Hotspells12_BR', 'Hotspells15_BR', 'Hotspells12_EA',
#        'Hotspells15_EA', 'Hotspells12_KE', 'Hotspells15_KE', 'Hotspells12_RW',
#        'Hotspells15_RW', 'Hotspells12_UG', 'Hotspells15_UG', 'Hotspells12_TZ',
#        'Hotspells15_TZ'],
#       dtype='object')

# %% [markdown]
# ### Plot a Line chart in Python using Matplotlib

# %%
col_mean = pd.DataFrame(hotspell.mean(axis=0));col_mean
mon_nms = col_mean.index[1:20];mon_nms
#col_mean[0][1:13]
yr_col = hotspell.columns[0];yr_col
yrs = hotspell[yr_col]; yrs #displays the year in the data
Br_hotspell = hotspell.columns[1];Br_hotspell
Br_12 = hotspell[Br_hotspell]; Br_12
Br_hotspell = hotspell.columns[2];Br_hotspell
Br_15 = hotspell[Br_hotspell]
#Br_15

# %%
plt.plot(yrs, Br_12, 'o-g')
plt.plot(yrs, Br_15, 'o-b')
plt.xlabel("Year", fontsize=14)
plt.ylabel("hotspell events", fontsize=14)
plt.title("Annual Number of hotspell events for Burundi", fontsize=14)
#legend 
plt.legend(['criteria 1.2', 'Criteria 1.5'])
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'hotspell_Burundi-tmean.jpeg')
plt.show()

# %% [markdown]
# ### Create a Line Chart in Python with Pandas DataFrame

# %%
df = pd.DataFrame(hotspell,columns=['Years','Hotspells12_BR'])
df1 = pd.DataFrame(hotspell,columns=['Years','Hotspells15_BR'])
plt.plot(df['Years'], df['Hotspells12_BR'], color='red', marker='o')
plt.plot(df['Years'], df1['Hotspells15_BR'], color='green', marker='o')
plt.title('Annual Number of hotspell events for Burundi', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('hotspell events', fontsize=14)
#legend 
plt.legend(['criteria 1.2', 'Criteria 1.5'])
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'hotspell_Burundi1-tmean.jpeg')
plt.show()

# %% [markdown]
# ### Ploting two graphs on one figure

# %%
fig = plt.figure(figsize=(15,5))
#pot1 using matplotlib
ax = plt.subplot(1,2,1)
plt.plot(yrs, Br_12, 'o-g')
plt.plot(yrs, Br_15, 'o-b')
plt.xlabel("Year", fontsize=14)
plt.ylabel("hotspell events", fontsize=14)
plt.title("Annual Number of hotspell events for Burundi", fontsize=14)
#legend 
plt.legend(['criteria 1.2', 'Criteria 1.5'])
plt.grid(True)

#plot2 using pandas
ax = plt.subplot(1,2,2)
df = pd.DataFrame(hotspell,columns=['Years','Hotspells12_BR'])
df1 = pd.DataFrame(hotspell,columns=['Years','Hotspells15_BR'])
plt.plot(df['Years'], df['Hotspells12_BR'], color='red', marker='o')
plt.plot(df['Years'], df1['Hotspells15_BR'], color='green', marker='o')
plt.title('Annual Number of hotspell events for Burundi', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('hotspell events', fontsize=14)
#legend 
plt.legend(['criteria 1.2', 'Criteria 1.5'])
plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'hotspell_Burundi3-tmean.jpeg')

# %%
fig = plt.figure(figsize=(15,5))
#plot1 using pandas
ax = plt.subplot(1,2,1)
df = pd.DataFrame(hotspell,columns=['Years','Hotspells12_BR'])
df1 = pd.DataFrame(hotspell,columns=['Years','Hotspells15_BR'])
plt.plot(df['Years'], df['Hotspells12_BR'], color='red', marker='o')
plt.plot(df['Years'], df1['Hotspells15_BR'], color='green', marker='o')
plt.title('Annual trend of night time hotspell events over Burundi', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('Number of hotspell events', fontsize=14)
plt.legend(['criteria >= 1.2degC of daily SAI in 5 consective days', 'criteria >= 1.5degC of daily SAI in 5 consective days'],loc = 'upper left')

#plot2 using pandas
ax = plt.subplot(1,2,2)
df2 = pd.DataFrame(hotspell,columns=['Years','Hotspells12_KE'])
df3 = pd.DataFrame(hotspell,columns=['Years','Hotspells15_KE'])
plt.plot(df['Years'], df2['Hotspells12_KE'], color='red', marker='o')
plt.plot(df['Years'], df3['Hotspells15_KE'], color='green', marker='o')
plt.title('Annual trend of night time hotspell events over Kenya', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('Number of hotspell events', fontsize=14)
plt.legend(['criteria >= 1.2degC of daily SAI in 5 consective days', 'criteria >= 1.5degC of daily SAI in 5 consective days'],loc = 'upper left')
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'hotspell1_tmin.jpeg')

# %%
fig = plt.figure(figsize=(15,5))
#plot3 using pandas
ax = plt.subplot(1,2,1)
df4 = pd.DataFrame(hotspell,columns=['Years','Hotspells12_RW'])
df5 = pd.DataFrame(hotspell,columns=['Years','Hotspells15_RW'])
plt.plot(df['Years'], df4['Hotspells12_RW'], color='red', marker='o')
plt.plot(df['Years'], df5['Hotspells15_RW'], color='green', marker='o')
plt.title('Annual trend of night time hotspell events over Rwanda', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('Number of hotspell events', fontsize=14)
plt.legend(['criteria >= 1.2degC of daily SAI in 5 consective days', 'criteria >= 1.5degC of daily SAI in 5 consective days'], loc = 'upper left')

#plot4 using pandas
ax = plt.subplot(1,2,2)
df6 = pd.DataFrame(hotspell,columns=['Years','Hotspells12_TZ'])
df7 = pd.DataFrame(hotspell,columns=['Years','Hotspells15_TZ'])
plt.plot(df['Years'], df6['Hotspells12_TZ'], color='red', marker='o')
plt.plot(df['Years'], df7['Hotspells15_TZ'], color='green', marker='o')
plt.title('Annual trend of night time hotspell events events over Tanzania', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('Number of hotspell events', fontsize=14)
plt.legend(['criteria >= 1.2degC of daily SAI in 5 consective days', 'criteria >= 1.5degC of daily SAI in 5 consective days'], loc = 'upper left')
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'hotspell2_tmin.jpeg')

# %%
fig = plt.figure(figsize=(15,5))
#plot5 using pandas
ax = plt.subplot(1,2,1)
df8 = pd.DataFrame(hotspell,columns=['Years','Hotspells12_UG'])
df9 = pd.DataFrame(hotspell,columns=['Years','Hotspells15_UG'])
plt.plot(df['Years'], df8['Hotspells12_UG'], color='red', marker='o')
plt.plot(df['Years'], df9['Hotspells15_UG'], color='green', marker='o')
plt.title('Annual trend of night time hotspell events over Uganda', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('Number of hotspell events', fontsize=14)
#legend 
plt.legend(['criteria >= 1.2degC of daily SAI in 5 consective days', 'criteria >= 1.5degC of daily SAI in 5 consective days'], loc = 'upper left')

#plot6 using pandas
ax = plt.subplot(1,2,2)
df10 = pd.DataFrame(hotspell,columns=['Years','Hotspells12_EA'])
df11 = pd.DataFrame(hotspell,columns=['Years','Hotspells15_EA'])
plt.plot(df['Years'], df10['Hotspells12_EA'], color='red', marker='o')
plt.plot(df['Years'], df11['Hotspells15_EA'], color='green', marker='o')
plt.title('Annual trend of night time hotspell events over East Africa', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('Number of hotspell events', fontsize=14)
#legend 
plt.legend(['criteria >= 1.2degC of daily SAI in 5 consective days', 'criteria >= 1.5degC of daily SAI in 5 consective days'], loc = 'upper left')
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'hotspell3_tmin.jpeg')

# %% [markdown]
# ### Plotting SST Anomaly

# %%
## Read in the data using the appropriate Library and by defining the correct path

sst = pd.read_csv(home_dir +'Annual_SST-anomaly.csv')
#hotspell             ## Prints out a sample of the data
#hotspell.info()      ## describe your data
sst.columns     ## Check the column headers
#sst.shape       ## Check the number of rows and columns
#sst.describe()  ## Get summary statistics about your data
#sst[["NINO1"]].describe()  ## Summary statistics on particular columns as a dataframe
#sst["NINO1"].describe()  ## Summary statistics on particular columns as a series
#sst.sort_values(by="NINO1", ascending = False) ## Sort the data in descending order
# Out:
# Index(['Year', 'NINO1', 'NINO2', 'NINO3', 'NINO4', 'NINO34', 'IOD_EAST',
#        'IOD_WEST', 'IOD_INDEX'],
#       dtype='object')

# %%
#PLOT1 SST Anomaly
df12 = pd.DataFrame(sst,columns=['Year','IOD_EAST'])
df13 = pd.DataFrame(sst,columns=['Year','IOD_WEST'])
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type
plt.plot(df12['Year'], df12['IOD_EAST'], color='red', marker='o')
plt.plot(df13['Year'], df13['IOD_WEST'], color='green', marker='o')
plt.title('Annual SST anomaly over Indian Ocean ', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('SST anomaly', fontsize=14)
plt.legend(['IOD-EAST', 'IOD-WEST'])
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'IOD_SST.jpeg')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
df12 = pd.DataFrame(sst,columns=['Year','IOD_EAST'])
plt.bar(df12['Year'], df12['IOD_EAST'], color='blue')
plt.title('Annual SST anomaly over Indian Ocean, IOD EAST', fontsize=18)
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type
plt.axhline(y = 0.8, color = 'gray', linestyle = '--')
plt.axhline(y = -0.8, color = 'gray', linestyle = '--')
plt.xlabel('Years', fontsize=18)
plt.ylabel('SST anomaly', fontsize=18)
plt.savefig(home_dir + 'python_plots/' + 'IOD_SST1.jpeg')
plt.show()

# %%
## Read in the data using the appropriate Library and by defining the correct path

RF = pd.read_csv(home_dir +'Rainfall_2022.csv')
#hotspell             ## Prints out a sample of the data
#hotspell.info()      ## describe your data
RF.columns     ## Check the column headers
# Out:
# Index(['Stations', 'January', 'February', 'March', 'April'], dtype='object')

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,6))

April = [107.8, 177.5, 152, 170.8,222.7,143.9,115.9,275.7,173.3,188.2,351.9,138.7,140,144,204.2,118.4,108.1,105.4,200.3,205.4]
May = [130.1, 112.8, 230, 113.2, 187.3,27.9,69,36.4,170.8,163.1,213.6,147.2,127.7,190.1,80.8,174.3,127.5,148.3,83.1,110.8]

n=20
r = np.arange(n)
width = 0.25
plt.bar(r, April, color = 'b',
width = width, edgecolor = 'black',
label='Rainfall April')
plt.bar(r + width, May, color = 'g',
width = width, edgecolor = 'black',
label='Rainfall May')
plt.xlabel("Stations", fontsize=30)
plt.ylabel("Monthly Rainfall (mm)", fontsize=20)
plt.title("Montly Rainfall for March and April 2022", fontsize=20)
# plt.grid(linestyle='--')
plt.xticks(r + width/2,['Arua','Kitgum','Gulu','Masindi','Kasese','Kabale','Mbarara','Entebbe','Kampala','Namulonge','Jinja','Tororo','Soroti','Mubende','Lira','Kibanda','Serere','Kawanda','Kamenyamigo','Kiige'])
plt.legend(fontsize=20)
plt.xticks(rotation=75)
plt.show()
plt.savefig(home_dir + 'python_plots/' + 'LTM.jpeg')

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(15,6))

X = ['Arua','Kitgum','Gulu','Masindi','Kasese','Kabale','Mbarara','Entebbe','Kampala','Namulonge','Jinja','Tororo','Soroti','Mubende','Lira','Kibanda','Serere','Kawanda','Kamenyamigo','Kiige']
Ygirls = [107.8, 177.5, 152, 170.8,222.7,143.9,115.9,275.7,173.3,188.2,351.9,138.7,140,144,204.2,118.4,108.1,105.4,200.3,205.4]
Zboys = [130.1, 112.8, 230, 113.2, 187.3,27.9,69,36.4,170.8,163.1,213.6,147.2,127.7,190.1,80.8,174.3,127.5,148.3,83.1,110.8]

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, Ygirls, 0.4, label = 'Girls')
plt.bar(X_axis + 0.2, Zboys, 0.4, label = 'Boys')

plt.xticks(X_axis, X)
plt.xlabel("Groups")
plt.ylabel("Number of Students")
plt.xticks(rotation=75)
plt.title("Number of Students in each group")
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
#plot1 SST Anomaly
ax = plt.subplot(1,2,1)
df14 = pd.DataFrame(sst,columns=['Year','IOD_INDEX'])
plt.plot(df14['Year'], df14['IOD_INDEX'], color='red', marker='o')
plt.title('Annual SST anomaly over Indian Ocean (1971-2021)', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('SST anomaly', fontsize=14)
plt.legend(['IOD region'])
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type
plt.axhline(y = 0.4, color = 'gray', linestyle = '--')
plt.axhline(y = -0.4, color = 'gray', linestyle = '--')
#plt.grid(True)

#plot2 SST aNOMALY
ax = plt.subplot(1,2,2)
df12 = pd.DataFrame(sst,columns=['Year','NINO34'])
plt.plot(df12['Year'], df12['NINO34'], color='red', marker='o')
plt.title('Annual SST anomaly over Pacific Ocean (1971-2021)', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('SST anomaly', fontsize=14)
plt.legend(['NINO 3.4 region'], loc = 'upper left')
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type
plt.axhline(y = 0.8, color = 'gray', linestyle = '--')
plt.axhline(y = -0.8, color = 'gray', linestyle = '--')
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'ENSO_SST.jpeg')
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
#plot1 SST Anomaly
ax = plt.subplot(1,2,1)
df12 = pd.DataFrame(sst,columns=['Year','IOD_EAST'])
df13 = pd.DataFrame(sst,columns=['Year','IOD_WEST'])
plt.plot(df12['Year'], df12['IOD_EAST'], color='red', marker='o')
plt.plot(df13['Year'], df13['IOD_WEST'], color='green', marker='o')
plt.title('Annual SST anomaly over Indian Ocean (1971-2021)', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('SST anomaly', fontsize=14)
plt.legend(['IOD-EAST region', 'IOD-WEST region'])
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type
#plt.grid(True)

#plot2 SST aNOMALY
ax = plt.subplot(1,2,2)
df12 = pd.DataFrame(sst,columns=['Year','NINO1'])
df13 = pd.DataFrame(sst,columns=['Year','NINO2'])
plt.plot(df12['Year'], df12['NINO1'], color='red', marker='o')
plt.plot(df13['Year'], df13['NINO2'], color='green', marker='o')
plt.title('Annual SST anomaly over Pacific Ocean (1971-2021)', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('SST anomaly', fontsize=14)
plt.legend(['NINO 1 region', 'NINO 2 region'], loc = 'upper left')
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type
plt.axhline(y = 0.8, color = 'gray', linestyle = '--')
plt.axhline(y = -0.8, color = 'gray', linestyle = '--')
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'ENSO1_SST.jpeg')
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
#plot1 SST Anomaly
ax = plt.subplot(1,2,1)
df12 = pd.DataFrame(sst,columns=['Year','NINO3'])
df13 = pd.DataFrame(sst,columns=['Year','NINO4'])
plt.plot(df12['Year'], df12['NINO3'], color='red', marker='o')
plt.plot(df13['Year'], df13['NINO4'], color='green', marker='o')
plt.title('Annual SST anomaly over Pacific Ocean (1971-2021)', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('SST anomaly', fontsize=14)
plt.legend(['NINO 3 region', 'NINO 4 region'], loc = 'upper left')
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type
plt.axhline(y = 0.8, color = 'gray', linestyle = '--')
plt.axhline(y = -0.8, color = 'gray', linestyle = '--')
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'ENSO2_SST.jpeg')
plt.show()

# %% [markdown]
# ### Plotting Anomaly temperature graphs

# %%
## Read in the data using the appropriate Library and by defining the correct path

Anomaly = pd.read_csv(home_dir +'Temperature_Anomaly-EA.csv')
#Anomaly             ## Prints out a sample of the data
#Anomaly.info()      ## describe your data
Anomaly.columns     ## Check the column headers
#Anomaly.shape       ## Check the number of rows and columns
#Anomaly.describe()  ## Get summary statistics about your data
#Anomaly[["tmax_Ug"]].describe()  ## Summary statistics on particular columns as a dataframe
#Anomaly["tmax_Ug"].describe()  ## Summary statistics on particular columns as a series
#Anomaly.sort_values(by="tmax_Ug", ascending = False) ## Sort the data in descending order
# Out:
# Index(['Year', 'tmax_Ug', 'tmax_KE', 'tmax_TZ', 'tmax_BR', 'tmax_RW',
#        'tmax_EA', 'tmin_Ug', 'tmin_KE', 'tmin_TZ', 'tmin_BR', 'tmin_RW',
#        'tmin_EA', 'tmean_Ug', 'tmean_KE', 'tmean_TZ', 'tmean_BR', 'tmean_RW',
#        'tmean_EA'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(15,5))
#plot1 temperature Anomaly
ax = plt.subplot(1,2,1)
df12 = pd.DataFrame(Anomaly,columns=['Year','tmax_KE'])
df13 = pd.DataFrame(Anomaly,columns=['Year','tmax_TZ'])
df14 = pd.DataFrame(Anomaly,columns=['Year','tmax_Ug'])
df15 = pd.DataFrame(Anomaly,columns=['Year','tmax_BR'])
df16 = pd.DataFrame(Anomaly,columns=['Year','tmax_RW'])
df17 = pd.DataFrame(Anomaly,columns=['Year','tmax_EA'])
plt.plot(df12['Year'], df12['tmax_KE'], color='red', marker='o')
plt.plot(df13['Year'], df13['tmax_TZ'], color='green', marker='o')
plt.plot(df14['Year'], df14['tmax_Ug'], color='blue', marker='o')
plt.plot(df15['Year'], df15['tmax_BR'], color='orange', marker='o')
plt.plot(df16['Year'], df16['tmax_RW'], color='brown', marker='o')
plt.plot(df17['Year'], df17['tmax_EA'], color='purple', marker='o')
plt.title('Trend of Annual Tmax Anomaly (1971-2021)', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('SAI', fontsize=14)
plt.legend(['Kenya', 'Tanzania','Uganda', 'Burundi', 'Rwanda', 'East Africa'])
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type

#plot2 temperature aNOMALY
ax = plt.subplot(1,2,2)
df12 = pd.DataFrame(Anomaly,columns=['Year','tmin_KE'])
df13 = pd.DataFrame(Anomaly,columns=['Year','tmin_TZ'])
df14 = pd.DataFrame(Anomaly,columns=['Year','tmin_Ug'])
df15 = pd.DataFrame(Anomaly,columns=['Year','tmin_BR'])
df16 = pd.DataFrame(Anomaly,columns=['Year','tmin_RW'])
df17 = pd.DataFrame(Anomaly,columns=['Year','tmin_EA'])
plt.plot(df12['Year'], df12['tmin_KE'], color='red', marker='o')
plt.plot(df13['Year'], df13['tmin_TZ'], color='green', marker='o')
plt.plot(df14['Year'], df14['tmin_Ug'], color='blue', marker='o')
plt.plot(df15['Year'], df15['tmin_BR'], color='orange', marker='o')
plt.plot(df16['Year'], df16['tmin_RW'], color='brown', marker='o')
plt.plot(df17['Year'], df17['tmin_EA'], color='purple', marker='o')
plt.title('Trend of Annual Tmin Anomaly (1971-2021)', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('SAI', fontsize=14)
plt.legend(['Kenya', 'Tanzania','Uganda', 'Burundi', 'Rwanda', 'East Africa'])
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'TEMP_ANOMALY.jpeg')
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
#plot1 temp Anomaly
ax = plt.subplot(1,2,1)
df12 = pd.DataFrame(Anomaly,columns=['Year','tmean_KE'])
df13 = pd.DataFrame(Anomaly,columns=['Year','tmean_TZ'])
df14 = pd.DataFrame(Anomaly,columns=['Year','tmean_Ug'])
df15 = pd.DataFrame(Anomaly,columns=['Year','tmean_BR'])
df16 = pd.DataFrame(Anomaly,columns=['Year','tmean_RW'])
df17 = pd.DataFrame(Anomaly,columns=['Year','tmean_EA'])
plt.plot(df12['Year'], df12['tmean_KE'], color='red', marker='o')
plt.plot(df13['Year'], df13['tmean_TZ'], color='green', marker='o')
plt.plot(df14['Year'], df14['tmean_Ug'], color='blue', marker='o')
plt.plot(df15['Year'], df15['tmean_BR'], color='orange', marker='o')
plt.plot(df16['Year'], df16['tmean_RW'], color='brown', marker='o')
plt.plot(df17['Year'], df17['tmean_EA'], color='purple', marker='o')
plt.title('Trend of Annual Tmean Anomaly (1971-2021)', fontsize=14)
plt.xlabel('Years', fontsize=14)
plt.ylabel('SAI', fontsize=14)
plt.legend(['Kenya', 'Tanzania','Uganda', 'Burundi', 'Rwanda', 'East Africa'])
plt.axhline(y = 0.0, color = 'black', linestyle = '-') # specifying horizontal line type
plt.savefig(home_dir + 'python_plots/' + 'TEMP_ANOMALY1.jpeg')
plt.show()

# %%
## Read in the data using the appropriate Library and by defining the correct path

cum = pd.read_csv(home_dir +'cummulative_RF-Kampala.csv')
#Anomaly             ## Prints out a sample of the data
cum.columns     ## Check the column headers
#Anomaly.shape       ## Check the number of rows and columns
#Anomaly.describe()  ## Get summary statistics about your data
#Anomaly[["tmax_Ug"]].describe()  ## Summary statistics on particular columns as a dataframe
#Anomaly["tmax_Ug"].describe()  ## Summary statistics on particular columns as a series
#Anomaly.sort_values(by="tmax_Ug", ascending = False) ## Sort the data in descending order
# Out:
# Index(['Months', 'Cumm_2010-2011', 'Cumm_2011-2012', 'Cumm_2021-2022',
#        'Cumm_LTM'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20,8))
df = pd.DataFrame(cum,columns=['Months','Cumm_2010-2011'])
df1 = pd.DataFrame(cum,columns=['Months','Cumm_2011-2012'])
df2 = pd.DataFrame(cum,columns=['Months','Cumm_2021-2022'])
df3 = pd.DataFrame(cum,columns=['Months','Cumm_LTM'])

plt.plot(df['Months'], df['Cumm_2010-2011'], color='red', marker='o')
plt.plot(df1['Months'], df1['Cumm_2011-2012'], color='green', marker='o')
plt.plot(df2['Months'], df2['Cumm_2021-2022'], color='brown', marker='o')
plt.plot(df3['Months'], df3['Cumm_LTM'], color='blue', marker='o')

plt.title('Kampala Cummulative Rainfall', fontsize=20)
plt.xlabel('Months', fontsize=20)
plt.ylabel('Cummulative Rainfall', fontsize=20)
#legend 
plt.legend(['Cumm_2010-2011', 'Cumm_2011-2012','Cumm_2021-2022','Cumm_LTM'])
#plt.grid(True)
plt.savefig(home_dir + 'python_plots/' + 'cumm_kla.jpeg')
plt.show()

# %% [markdown]
# ###                                     GOD PROVIDES
